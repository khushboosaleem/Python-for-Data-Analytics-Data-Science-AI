# %% [markdown]
# # Object-Oriented Programming for Data Science, Data Analytics & AI
#
#
# This notebook teaches Object-Oriented Programming from **basic to advanced level** with solved examples.
#
# ### You will learn
# - Classes and objects
# - Constructor and `self`
# - Instance and class attributes
# - Instance, class and static methods
# - Encapsulation
# - Inheritance
# - Polymorphism
# - Abstraction
# - Magic methods
# - Composition and mixins
# - OOP use in Data Science, Data Analytics, Machine Learning and AI
# - End-to-end solved mini projects
#
# Every important Python line contains an English comment.

# %% [markdown]
# # 1. Why OOP is Useful in DS, DA and AI
#
#
# OOP helps us organize large projects into reusable components.
#
# ### In Data Science
# We can create separate classes for:
# - Data loading
# - Data cleaning
# - Feature engineering
# - Model training
# - Model evaluation
#
# ### In Data Analytics
# We can create classes for:
# - Reports
# - Dashboards
# - Data validation
# - Visualizations
# - Automated analysis
#
# ### In AI and Machine Learning
# We can create classes for:
# - Models
# - Agents
# - Environments
# - Training pipelines
# - Prediction systems
#
# This makes code easier to reuse, test, maintain and scale.

# %% [markdown]
# # 2. Basic Class
#
# A class is a blueprint used to create objects.

# %%
# Create a class named Student.
class Student:
    # Create a method that displays a message.
    def learn(self):
        # Print a learning message.
        print("The student is learning Python.")

# Create an object from the Student class.
student_one = Student()

# Call the method using the object.
student_one.learn()

# %% [markdown]
# # 3. Objects
#
# An object is an instance created from a class.

# %%
# Create a class named Laptop.
class Laptop:
    # Create a method that displays laptop information.
    def show_info(self):
        # Print the laptop brand.
        print("Brand:", self.brand)
        # Print the laptop RAM.
        print("RAM:", self.ram)

# Create the first Laptop object.
laptop_one = Laptop()

# Store the brand in the object.
laptop_one.brand = "Dell"

# Store the RAM in the object.
laptop_one.ram = "16 GB"

# Display the object information.
laptop_one.show_info()

# %% [markdown]
# # 4. Constructor and self
#
# `__init__()` runs automatically when an object is created. `self` represents the current object.

# %%
# Create a class named Employee.
class Employee:
    # Define a constructor that receives employee data.
    def __init__(self, name, salary):
        # Store the employee name in the current object.
        self.name = name
        # Store the employee salary in the current object.
        self.salary = salary

    # Create a method that displays employee data.
    def show_details(self):
        # Print the employee name.
        print("Name:", self.name)
        # Print the employee salary.
        print("Salary:", self.salary)

# Create an Employee object with constructor values.
employee_one = Employee("Ali", 70000)

# Display employee details.
employee_one.show_details()

# %% [markdown]
# # 5. Instance Attributes and Class Attributes
#
# Instance attributes belong to individual objects. Class attributes are shared by all objects.

# %%
# Create a class named DataCourse.
class DataCourse:
    # Create a class attribute shared by all objects.
    institute = "Data Learning Academy"

    # Define a constructor for course data.
    def __init__(self, course_name, duration):
        # Store the course name in the object.
        self.course_name = course_name
        # Store the course duration in the object.
        self.duration = duration

# Create the first course object.
course_one = DataCourse("Data Science", "6 Months")

# Create the second course object.
course_two = DataCourse("Data Analytics", "4 Months")

# Display the shared class attribute.
print(DataCourse.institute)

# Display the first object's course name.
print(course_one.course_name)

# Display the second object's course name.
print(course_two.course_name)

# %% [markdown]
# # 6. Instance Methods
#
# Instance methods work with object-specific data.

# %%
# Create a class named Dataset.
class Dataset:
    # Define a constructor for dataset values.
    def __init__(self, name, rows):
        # Store the dataset name.
        self.name = name
        # Store the number of rows.
        self.rows = rows

    # Create an instance method that displays dataset information.
    def describe(self):
        # Print the dataset name.
        print("Dataset:", self.name)
        # Print the number of rows.
        print("Rows:", self.rows)

# Create a Dataset object.
dataset = Dataset("Customer Data", 5000)

# Call the instance method.
dataset.describe()

# %% [markdown]
# # 7. Class Methods
#
# Class methods work with class-level data and use `cls`.

# %%
# Create a class named ModelConfig.
class ModelConfig:
    # Create a class attribute for the default learning rate.
    learning_rate = 0.01

    # Create a class method for updating the learning rate.
    @classmethod
    def update_learning_rate(cls, new_rate):
        # Update the class-level learning rate.
        cls.learning_rate = new_rate

# Display the original learning rate.
print(ModelConfig.learning_rate)

# Update the learning rate using the class method.
ModelConfig.update_learning_rate(0.001)

# Display the updated learning rate.
print(ModelConfig.learning_rate)

# %% [markdown]
# # 8. Static Methods
#
# Static methods perform utility tasks and do not use `self` or `cls`.

# %%
# Create a class named DataValidator.
class DataValidator:
    # Create a static method that checks a value.
    @staticmethod
    def is_positive(value):
        # Return True when the value is positive.
        return value > 0

# Check a positive value.
print(DataValidator.is_positive(10))

# Check a negative value.
print(DataValidator.is_positive(-5))

# %% [markdown]
# # 9. Encapsulation
#
# Encapsulation hides internal data and protects it from direct access.

# %%
# Create a class named SecureDataset.
class SecureDataset:
    # Define a constructor for dataset information.
    def __init__(self, name, records):
        # Store the public dataset name.
        self.name = name
        # Store the records as a private attribute.
        self.__records = records

    # Create a getter method for the private records.
    def get_records(self):
        # Return the private records safely.
        return self.__records

    # Create a setter method for updating records.
    def set_records(self, records):
        # Check that the number of records is valid.
        if records >= 0:
            # Update the private records.
            self.__records = records

# Create a SecureDataset object.
secure_data = SecureDataset("Sales Data", 1000)

# Display the private records through the getter.
print(secure_data.get_records())

# Update the private records through the setter.
secure_data.set_records(1200)

# Display the updated records.
print(secure_data.get_records())

# %% [markdown]
# # 10. Inheritance
#
# Inheritance allows a child class to reuse and extend the parent class.

# %%
# Create a parent class named DataProcessor.
class DataProcessor:
    # Create a method for loading data.
    def load_data(self):
        # Print a loading message.
        print("Data is loaded.")

# Create a child class named DataCleaner.
class DataCleaner(DataProcessor):
    # Create a method for cleaning data.
    def clean_data(self):
        # Print a cleaning message.
        print("Missing values are removed.")

# Create a DataCleaner object.
cleaner = DataCleaner()

# Call the inherited parent method.
cleaner.load_data()

# Call the child class method.
cleaner.clean_data()

# %% [markdown]
# # 11. Multilevel Inheritance
#
# A class can inherit from another child class.

# %%
# Create a base class named DataLoader.
class DataLoader:
    # Create a data loading method.
    def load(self):
        # Print a loading message.
        print("Loading data...")

# Create a child class named Cleaner.
class Cleaner(DataLoader):
    # Create a data cleaning method.
    def clean(self):
        # Print a cleaning message.
        print("Cleaning data...")

# Create another child class named Trainer.
class Trainer(Cleaner):
    # Create a model training method.
    def train(self):
        # Print a training message.
        print("Training model...")

# Create a Trainer object.
pipeline = Trainer()

# Call the inherited loading method.
pipeline.load()

# Call the inherited cleaning method.
pipeline.clean()

# Call the training method.
pipeline.train()

# %% [markdown]
# # 12. Multiple Inheritance
#
# A class can inherit features from more than one parent class.

# %%
# Create a class that provides logging features.
class Logger:
    # Create a logging method.
    def log(self, message):
        # Print the log message.
        print("LOG:", message)

# Create a class that provides validation features.
class Validator:
    # Create a validation method.
    def validate(self, value):
        # Return True when the value is not missing.
        return value is not None

# Create a class that inherits from both parent classes.
class DataPipeline(Logger, Validator):
    # Create a processing method.
    def process(self, value):
        # Check whether the value is valid.
        if self.validate(value):
            # Log a success message.
            self.log("Value processed successfully.")

# Create a DataPipeline object.
pipeline = DataPipeline()

# Process a sample value.
pipeline.process(25)

# %% [markdown]
# # 13. Method Overriding
#
# A child class can replace a parent class method with its own version.

# %%
# Create a parent model class.
class MLModel:
    # Create a prediction method.
    def predict(self):
        # Print a general prediction message.
        print("Making a general prediction.")

# Create a child classification model.
class ClassificationModel(MLModel):
    # Override the parent prediction method.
    def predict(self):
        # Print a classification prediction message.
        print("Predicting a class label.")

# Create a ClassificationModel object.
model = ClassificationModel()

# Call the overridden method.
model.predict()

# %% [markdown]
# # 14. Polymorphism
#
# The same method name can behave differently for different objects.

# %%
# Create a class named LinearRegressionModel.
class LinearRegressionModel:
    # Create a training method.
    def train(self):
        # Print a regression training message.
        print("Training a Linear Regression model.")

# Create a class named DecisionTreeModel.
class DecisionTreeModel:
    # Create a training method.
    def train(self):
        # Print a decision tree training message.
        print("Training a Decision Tree model.")

# Create a list containing different model objects.
models = [LinearRegressionModel(), DecisionTreeModel()]

# Loop through each model object.
for model in models:
    # Call the same method on different model types.
    model.train()

# %% [markdown]
# # 15. Abstraction
#
# Abstraction defines a common interface while hiding implementation details.

# %%
# Import abstract base class tools.
from abc import ABC, abstractmethod

# Create an abstract model class.
class BaseModel(ABC):
    # Declare an abstract training method.
    @abstractmethod
    def train(self):
        # Leave the method without implementation.
        pass

# Create a concrete model class.
class SimpleModel(BaseModel):
    # Implement the required training method.
    def train(self):
        # Print a training message.
        print("The model is training.")

# Create a SimpleModel object.
simple_model = SimpleModel()

# Call the implemented training method.
simple_model.train()

# %% [markdown]
# # 16. Magic Methods
#
# Magic methods customize object behavior.

# %%
# Create a class named Report.
class Report:
    # Define a constructor for report information.
    def __init__(self, title, pages):
        # Store the report title.
        self.title = title
        # Store the number of pages.
        self.pages = pages

    # Customize the printable object representation.
    def __str__(self):
        # Return formatted report information.
        return f"{self.title} contains {self.pages} pages."

    # Customize the length behavior.
    def __len__(self):
        # Return the number of pages.
        return self.pages

# Create a Report object.
report = Report("Sales Analysis", 15)

# Print the object using the custom string method.
print(report)

# Display the custom object length.
print(len(report))

# %% [markdown]
# # 17. Composition
#
# Composition means one class contains an object of another class.

# %%
# Create a class named DataCleaner.
class DataCleaner:
    # Create a cleaning method.
    def clean(self):
        # Print a cleaning message.
        print("Data has been cleaned.")

# Create a class named AnalysisPipeline.
class AnalysisPipeline:
    # Define a constructor for the pipeline.
    def __init__(self):
        # Create a DataCleaner object inside the pipeline.
        self.cleaner = DataCleaner()

    # Create a pipeline execution method.
    def run(self):
        # Use the internal cleaner object.
        self.cleaner.clean()
        # Print a completion message.
        print("Analysis pipeline completed.")

# Create an AnalysisPipeline object.
analysis_pipeline = AnalysisPipeline()

# Run the complete pipeline.
analysis_pipeline.run()

# %% [markdown]
# # 18. OOP in Data Analytics — Solved Mini Project
#
# This project creates a reusable sales analysis class.

# %%
# Import pandas for data analysis.
import pandas as pd

# Create a class named SalesAnalyzer.
class SalesAnalyzer:
    # Define a constructor that receives sales data.
    def __init__(self, data):
        # Store the provided DataFrame.
        self.data = data

    # Create a method that calculates total sales.
    def total_sales(self):
        # Return the sum of the Sales column.
        return self.data["Sales"].sum()

    # Create a method that calculates average sales.
    def average_sales(self):
        # Return the mean of the Sales column.
        return self.data["Sales"].mean()

    # Create a method that finds the best product.
    def best_product(self):
        # Find the row index containing the maximum sales value.
        best_index = self.data["Sales"].idxmax()
        # Return the product name from the best row.
        return self.data.loc[best_index, "Product"]

# Create sample sales data.
sales_data = pd.DataFrame({
    # Create the Product column.
    "Product": ["Bag", "Jewelry", "Keychain", "Purse"],
    # Create the Sales column.
    "Sales": [45000, 62000, 28000, 71000]
})

# Create a SalesAnalyzer object.
sales_analyzer = SalesAnalyzer(sales_data)

# Display the total sales.
print("Total Sales:", sales_analyzer.total_sales())

# Display the average sales.
print("Average Sales:", sales_analyzer.average_sales())

# Display the best-selling product.
print("Best Product:", sales_analyzer.best_product())

# %% [markdown]
# # 19. OOP in Data Science — Solved ML Pipeline
#
# This project organizes data preparation, model training and evaluation inside one reusable class.

# %%
# Import the required scikit-learn tools.
from sklearn.datasets import load_iris

# Import the train-test split function.
from sklearn.model_selection import train_test_split

# Import the StandardScaler class.
from sklearn.preprocessing import StandardScaler

# Import the LogisticRegression model.
from sklearn.linear_model import LogisticRegression

# Import the accuracy score function.
from sklearn.metrics import accuracy_score

# Create a class named ClassificationPipeline.
class ClassificationPipeline:
    # Define a constructor that receives features and labels.
    def __init__(self, X, y):
        # Store the feature data.
        self.X = X
        # Store the target labels.
        self.y = y
        # Create a StandardScaler object.
        self.scaler = StandardScaler()
        # Create a LogisticRegression model object.
        self.model = LogisticRegression(max_iter=300)

    # Create a method for splitting and scaling the data.
    def prepare_data(self):
        # Split the data into training and testing sets.
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(
            self.X,
            self.y,
            test_size=0.2,
            random_state=42
        )
        # Fit the scaler and transform the training data.
        self.X_train = self.scaler.fit_transform(self.X_train)
        # Transform the testing data using the fitted scaler.
        self.X_test = self.scaler.transform(self.X_test)

    # Create a method for training the model.
    def train(self):
        # Train the model using the prepared training data.
        self.model.fit(self.X_train, self.y_train)

    # Create a method for evaluating the model.
    def evaluate(self):
        # Generate predictions for the testing data.
        predictions = self.model.predict(self.X_test)
        # Calculate and return the model accuracy.
        return accuracy_score(self.y_test, predictions)

    # Create a method for predicting new samples.
    def predict(self, new_data):
        # Scale the new data using the fitted scaler.
        scaled_data = self.scaler.transform(new_data)
        # Return the model predictions.
        return self.model.predict(scaled_data)

# Load the Iris dataset.
iris = load_iris()

# Store the feature values.
X = iris.data

# Store the target labels.
y = iris.target

# Create a ClassificationPipeline object.
ml_pipeline = ClassificationPipeline(X, y)

# Prepare the dataset.
ml_pipeline.prepare_data()

# Train the classification model.
ml_pipeline.train()

# Display the model accuracy.
print("Model Accuracy:", ml_pipeline.evaluate())

# Create one new flower sample.
new_flower = [[5.1, 3.5, 1.4, 0.2]]

# Predict the class of the new flower.
print("Predicted Class:", ml_pipeline.predict(new_flower))

# %% [markdown]
# # 20. OOP in AI — Simple Intelligent Agent
#
# An AI agent can be represented as a class with state and decision-making behavior.

# %%
# Create a class named SmartAgent.
class SmartAgent:
    # Define a constructor for the agent.
    def __init__(self, name):
        # Store the agent name.
        self.name = name
        # Store the initial energy level.
        self.energy = 100

    # Create a method for making a decision.
    def decide(self, temperature):
        # Check whether the temperature is high.
        if temperature > 35:
            # Return the cooling decision.
            return "Turn on cooling system"
        # Check whether the temperature is low.
        if temperature < 15:
            # Return the heating decision.
            return "Turn on heating system"
        # Return the normal condition decision.
        return "Keep the system unchanged"

    # Create a method for using energy.
    def use_energy(self, amount):
        # Reduce the agent energy level.
        self.energy -= amount

# Create a SmartAgent object.
agent = SmartAgent("Temperature Agent")

# Display the agent decision.
print(agent.decide(40))

# Reduce the agent energy.
agent.use_energy(10)

# Display the remaining energy.
print("Remaining Energy:", agent.energy)

# %% [markdown]
# # 21. Advanced OOP Project — Reusable End-to-End Data Pipeline
#
# This final project combines abstraction, inheritance, composition and polymorphism.

# %%
# Import abstract base class tools.
from abc import ABC, abstractmethod

# Import pandas for DataFrame operations.
import pandas as pd

# Create an abstract base component class.
class PipelineComponent(ABC):
    # Declare a required run method.
    @abstractmethod
    def run(self, data):
        # Leave the method without implementation.
        pass

# Create a data cleaning component.
class MissingValueCleaner(PipelineComponent):
    # Implement the required run method.
    def run(self, data):
        # Return a copy with missing values removed.
        return data.dropna()

# Create a feature engineering component.
class RevenueFeatureEngineer(PipelineComponent):
    # Implement the required run method.
    def run(self, data):
        # Create a copy to protect the original DataFrame.
        result = data.copy()
        # Create a Revenue column from Quantity and Price.
        result["Revenue"] = result["Quantity"] * result["Price"]
        # Return the transformed DataFrame.
        return result

# Create a reusable pipeline class.
class DataPipeline:
    # Define a constructor for pipeline components.
    def __init__(self, components):
        # Store the ordered pipeline components.
        self.components = components

    # Create a method that executes all components.
    def run(self, data):
        # Store the initial data.
        result = data
        # Loop through every pipeline component.
        for component in self.components:
            # Run the current component on the data.
            result = component.run(result)
        # Return the final transformed data.
        return result

# Create sample business data.
business_data = pd.DataFrame({
    # Create the Product column.
    "Product": ["Bag", "Purse", "Jewelry", "Keychain"],
    # Create the Quantity column with one missing value.
    "Quantity": [5, 3, None, 10],
    # Create the Price column.
    "Price": [2500, 4000, 1500, 500]
})

# Create the list of pipeline components.
components = [MissingValueCleaner(), RevenueFeatureEngineer()]

# Create the complete data pipeline.
data_pipeline = DataPipeline(components)

# Run the complete pipeline.
final_data = data_pipeline.run(business_data)

# Display the processed data.
final_data

# %% [markdown]
# # 22. Final Summary
#
#
# ### Basic Level
# - Class
# - Object
# - Constructor
# - `self`
# - Attributes
# - Methods
#
# ### Intermediate Level
# - Encapsulation
# - Inheritance
# - Polymorphism
# - Abstraction
# - Class and static methods
#
# ### Advanced Level
# - Magic methods
# - Multiple inheritance
# - Composition
# - Reusable pipelines
# - Real Data Analytics, Data Science and AI projects
#
# ### Main Benefit
# OOP helps you write modular, reusable, scalable and industry-ready Python code.
